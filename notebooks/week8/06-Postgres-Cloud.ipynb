# %% [markdown]
# ### Import Dependencies

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# ### Setup the database

# %%
# Get db password 

from dotenv import load_dotenv
from pathlib import Path
import os

# Path to .env two levels up
env_path = Path.cwd().parents[1] / ".env"
print(env_path)

load_dotenv(env_path)

# Access password
MY_PASSWORD = os.getenv("SUPABASE_PASSWORD")
# Out:
# /home/k/AI-Engineering-Bootcamp/ShoppingAssistant_SwirlAI/.env

# %%
import psycopg2
from dotenv import load_dotenv
import os

# Load environment variables from .env
env_path = Path.cwd().parents[1] / ".env"
print(env_path)
load_dotenv(env_path)

# Fetch variables
# USER = 'postgres.bydnmxkqwjsofgtzmfpl'
USER = 'kevin.j.shipley@gmail.com.bydnmxkqwjsofgtzmfpl'

PASSWORD = os.getenv("SUPABASE_PASSWORD")
HOST = 'aws-1-us-east-2.pooler.supabase.com'
# PORT = 6543
PORT = 5432
# DBNAME = 'ShoppingAssistant'
DBNAME = 'postgres'
POOL_MODE = 'session'

# print(PASSWORD)

# Connect to the database
try:
    connection = psycopg2.connect(
        user=USER,
        password=PASSWORD,
        host=HOST,
        port=PORT,
        dbname=DBNAME,
        # pool_mode=POOL_MODE
    )
    print("Connection successful!")
    
    # Create a cursor to execute SQL queries
    cursor = connection.cursor()
    
    # Example query
    cursor.execute("SELECT NOW();")
    result = cursor.fetchone()
    print("Current Time:", result)

    # Close the cursor and connection
    cursor.close()
    connection.close()
    print("Connection closed.")

except Exception as e:
    print(f"Failed to connect: {e}")
# Out:
# /home/k/AI-Engineering-Bootcamp/ShoppingAssistant_SwirlAI/.env
# sinbad-stoker-per-toaster
# Failed to connect: connection to server at "aws-1-us-east-2.pooler.supabase.com" (3.131.201.192), port 5432 failed: FATAL:  Authentication error, reason: "There is no user 'kevin.j.shipley@gmail.com' in the database. Please create it or change the user in the config", context: Handshake
# connection to server at "aws-1-us-east-2.pooler.supabase.com" (3.131.201.192), port 5432 failed: FATAL:  Authentication error, reason: "There is no user 'kevin.j.shipley@gmail.com' in the database. Please create it or change the user in the config", context: Handshake

# %%
# conn_string = (
#     f"postgresql://postgres:{MY_PASSWORD}"
#     "@db.bydnmxkqwjsofgtzmfpl.supabase.co:5432/postgres"
# )

conn_string = (
    f"postgresql://postgres.bydnmxkqwjsofgtzmfpl:{MY_PASSWORD}@aws-1-us-east-2.pooler.supabase.com:6543/postgres"
)

with PostgresSaver.from_conn_string(conn_string) as checkpointer:
    checkpointer.setup()
